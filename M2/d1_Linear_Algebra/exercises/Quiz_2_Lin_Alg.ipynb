# %% [markdown]
# ## Linear Algebra Quiz #2
#
# ![title](./img/2_1.jpeg)
#
# We strongly suggest working with numpy :)

# %%
#Do your imports here
import numpy as np

# %% [markdown]
# ![title](./img/2_2.png)
# - Which vectors below define a plane spanned by a linear combination?

# %%
def plane(a,b,c):
    #returns false if the vectors do define a plane and returns which are those vectors if true
    
    matrix = np.stack((a,b,c)) #Join a sequence of arrays along a new axis.
    
    lambdas, V = np.linalg.eig(matrix.T) 
    
    e = 0.000000001
    
    plane_test = abs(lambdas) > e 
    
    if plane_test.sum() >= 2:
        
        print('Vectors form a plane!')
        
        vectors = matrix[plane_test]
        return vectors
    else:
        print('Vectors are all linearly dependent. No plane exists.')
        
# Harder exercise

#def complete_plane(#inputs):
    
#returns the first set of vectors to complete a plane, false otherwise

# %%
def plane_modula(a,b,c):
    #returns false if the vectors do define a plane and returns which are those vectors if true
    ab = a%b
    bc = b%c
    ac = a%c
    zero_vec = np.zeros(len(a), dtype = int)
    
    if ab != zero_vec:
        return f'Vectors form a plane!  a: {a}   b: {b}'
    elif bc != zero_vec:
        return f'Vectors form a plane! b: {b} , c: {c}'
    elif ac != zero_vec:
        return f'Vectors form a plane! c: {a} c: {c}'
    else:
        print('Vectors are all linearly dependent. No plane exists.')

# %%
ab = a%b
bc = b%c
ac = a%c
zero_vec = np.zeros(len(a), dtype = int)

# %%
print(a%b)
print(ab)
print(zero_vec)
if ab == zero_vec :
    print(True)
# Out:
# [1 0 1]
# [1 0 1]
# [0 0 0]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-112-d73b07b573c0> in <module>
#       2 print(ab)
#       3 print(zero_vec)
# ----> 4 if ab == zero_vec :
#       5     print(True)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
a = np.array([1,2,3])
b = np.array([2,2,2])
c = np.array([8,8,8])

# %%
print(plane_modula(a,b,c))
print(plane(a,b,c))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-104-c706ec1f3bd3> in <module>
# ----> 1 print(plane_modula(a,b,c))
#       2 print(plane(a,b,c))
#
# <ipython-input-103-011c4c3973d7> in plane_modula(a, b, c)
#       6     zero_vec = np.zeros(len(a), dtype = int)
#       7
# ----> 8     if ab != zero_vec:
#       9         return f'Vectors form a plane!  a: {a}   b: {b}'
#      10     elif bc != zero_vec:
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
#any linear combiniation for a plane
#which dont forms a plane 
#linear dependet for the second equation /5 then its the same

# %% [markdown]
# ![title](./img/2_3.png)
# - What is the solution for a and b?

# %%
# do you need a function for this? What is the most efficient way to solve it?

# %% [markdown]
# ![title](./img/2_4.png)
# - What is the solution for a and b?

# %%
# Idem. Do you need a function for this? What is the most efficient way to solve it?

#same equation but diffrent solution !!! Wrong !!!!!!!
