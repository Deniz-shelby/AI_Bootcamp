# %% [markdown]
# ## Linear Algebra Quiz #1
#
# ![title](./img/1_0.jpeg)
#
# We strongly suggest working with numpy :)

# %%
#Do your imports here
import numpy as np

# %% [markdown]
# ![title](./img/1_1.png)

# %%
# type a function that given a 3_dimensional vector it is able to calculate its magnitude

def magnitude_3(a,b,c):
    list1 = [a,b,c]
    return np.linalg.norm(list1)


# type a function that given a n_dimensional vector it is able to calculate its magnitude
# if you want to try this from python (not jupyter notebook) https://docs.python.org/3/library/argparse.html would be a good addition
# if you are doing this from a jupyter notebook only, you can try to promt the user for an input  

def magnitude_complete(*args):
    X = []   
    for arg in args:
        X.append(arg)    
    return np.linalg.norm(X)

# %%
magnitude_3(1,2,3)
# Out:
# 3.7416573867739413

# %% [markdown]
# uncomment the following line when you are ready to test

# %%
magnitude_complete(1) == 1.0
magnitude_complete((1,2)) >= 2.236
magnitude_complete((1,2,3)) >= 3.741
#magnitude_complete(1,2,3,4,5) >= 5.477
#magnitude_complete(1,2,3,4,5) >= 7.416
# Out:
# True

# %% [markdown]
# ![title](./img/1_2.png)

# %%
def magnitude_vectors(a, b):
    vec = [a , b]
    return np.linalg.norm(vec)
    #checks that size is equal
    
    #returns the magnitude

# %% [markdown]
# ![title](./img/1_3.png)

# %%
def direction_vectors(a, b):
    #checks that size is equal
    return np.cross(a,b)
    #returns the magnitude
    
# or if you want to do it all in one batch:
def magdir_vectors(a, b):
    #checks that size is equal
    return f'The magnitude of a + b is {magnitude_vectors(a, b)} and the direction is {direction_vectors(a, b)}'
    
    #returns the magnitude and direction in a nicely printed format 
    #"The magnitude of a + b is X and the direction is Y"

# %%
a = [5,1]
b = [-4,-1]
magdir_vectors(a,b)
# Out:
# 'The magnitude of a + b is 6.557438524302 and the direction is -1'

# %% [markdown]
# ![title](./img/1_4.png)
# - What is the magnitude of αx⃗?
# - If α>0, will the direction of the resulting vector change?
# - If α<0, will the direction of the resulting vector change?
# - If −1<α<1, will ∥αx⃗∥  increase, decrease or stay the same?

# %%
def alpha_magnitude(alpha, b): ### ???????
    #returns the resulting magnitude, if the direction has changed and what has happened to the vector
    b = np.array(b)
    a = b * np .arctan(alpha)
    a = np.array(a)
    vec = [a,b]
    mag = np.linalg.norm(vec)
    direction = direction_vectors(a, b)
    return f'The magnitude of a + b is {mag} and the direction is '

# %%
alpha_magnitude(30,10)
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# <ipython-input-102-5745f98808d6> in <module>
# ----> 1 alpha_magnitude(30,10)
#
# <ipython-input-101-57279adbab57> in alpha_magnitude(alpha, b)
#       6     vec = [a,b]
#       7     mag = np.linalg.norm(vec)
# ----> 8     direction = direction_vectors(a, b)
#       9     return f'The magnitude of a + b is {mag} and the direction is '
#
# <ipython-input-80-f1e9182006c7> in direction_vectors(a, b)
#       1 def direction_vectors(a, b):
#       2     #checks that size is equal
# ----> 3     return np.cross(a,b)
#       4     #returns the magnitude
#       5
#
# <__array_function__ internals> in cross(*args, **kwargs)
#
# /opt/anaconda3/envs/condaenv/lib/python3.8/site-packages/numpy/core/numeric.py in cross(a, b, axisa, axisb, axisc, axis)
#    1569     b = asarray(b)
#    1570     # Check axisa and axisb are within bounds
# -> 1571     axisa = normalize_axis_index(axisa, a.ndim, msg_prefix='axisa')
#    1572     axisb = normalize_axis_index(axisb, b.ndim, msg_prefix='axisb')
#    1573
#
# AxisError: axisa: axis -1 is out of bounds for array of dimension 0
