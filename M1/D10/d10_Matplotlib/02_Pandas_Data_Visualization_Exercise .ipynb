# %% [markdown]
# # Pandas Data Visualization Exercise
#
# This is just a quick exercise for you to review the various plots we showed earlier. Use **df3** to replicate the following plots.

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
data = {"a": np.random.random(500),
        "b": np.random.random(500),
        "c": np.random.random(500),
        "d": np.random.random(500)}
df3 = pd.DataFrame(data)
# %matplotlib inline

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       500 non-null    float64
#  1   b       500 non-null    float64
#  2   c       500 non-null    float64
#  3   d       500 non-null    float64
# dtypes: float64(4)
# memory usage: 15.8 KB

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.144086  0.107790  0.620162  0.698924
# 1  0.219336  0.300594  0.345672  0.181506
# 2  0.062787  0.683066  0.441339  0.793738
# 3  0.904447  0.735442  0.315846  0.815924
# 4  0.315326  0.369250  0.402800  0.404564

# %% [markdown]
# **Recreate this scatter plot of b vs a. Note the color and size of the points. Also note the figure size. See if you can figure out how to stretch it in a similar fashion. Remeber back to your matplotlib lecture...**

# %%
# thicks inside on top and right ?
fig, ax = plt.subplots(figsize=(12,3))
plt.scatter(df3['a'],df3['b'],
            color='red',
            edgecolors='black',
           s= 50) #scatter(x,y)
plt.ylim(-0.2,1.2)
plt.xlim(-0.2,1.2)
plt.xlabel('a')
plt.ylabel('b')
plt.tick_params(axis='both',direction='in',top=True,right=True)
plt.show()

# %%
#DO NOT TOUCH ME

# %% [markdown]
# **Create a histogram of the 'a' column.**

# %%
fig, ax = plt.subplots(figsize=(7,5))
plt.hist(df3['a'],color='blue',edgecolor='black')
plt.xlim(0.0,1.0)
plt.ylabel('Frequency')
plt.tick_params(axis='both',direction='in',top=True,right=True)
plt.show()

# %%
#DO NOT TOUCH ME

# %% [markdown]
# **These plots are okay, but they don't look very polished. Use style sheets to set the style to 'ggplot' and redo the histogram from above. Also figure out how to add more bins to it.***

# %%
plt.style.use('ggplot')
fig, ax = plt.subplots(figsize=(7,5))
plt.hist(df3['a'],bins = 25,color='salmon', alpha=0.7,edgecolor='white')
plt.xlim(0.0,1.0)
plt.ylabel('Frequency')
plt.tick_params(axis='both',direction='out',top=True,right=True)
plt.show()

# %%
#DO NOT TOUCH ME

# %% [markdown]
# **Create a boxplot comparing the a and b columns.**

# %%
df = [df3['a'],df3['b']]
fig, ax = plt.subplots(figsize=(10,8))
box = plt.boxplot(df,
                  boxprops = dict(
                      color='r'),
                  whiskerprops = dict(
                      linestyle='--',
                      linewidth=2,
                      color='r'),
                 medianprops = dict(
                     linestyle='-',
                     color = 'b'))
#for _, line_list in box.items():
#    for line in line_list:
#        line.set_color('r')
ax.set_xticklabels(['a', 'b'])
plt.tick_params(axis='both',direction='out',top=True,right=True)
plt.ylim(0.0,1.0)
# Out:
# (0.0, 1.0)

# %%
#DO NOT TOUCH ME

# %% [markdown]
# **Create a kde plot of the 'd' column**

# %%
df3['d'].plot.kde()
plt.ylim(0.0,1.2)
plt.xlim(-.5,1.5)
plt.xticks(np.arange(-0.5,1.6, 0.5))
plt.tick_params(axis='both',direction='out',top=True,right=True)
plt.show()

# %%
#DO NOT TOUCH ME

# %% [markdown]
# **Figure out how to increase the linewidth and make the linestyle dashed. (Note: You would usually not dash a kde plot line)**

# %%
sb.kdeplot(df3['d'],linestyle='--',linewidth=4)
plt.ylim(0.0,1.2)
plt.xlim(-.5,1.5)
plt.xticks(np.arange(-0.5,1.6, 0.5))
plt.tick_params(axis='both',direction='out',top=True,right=True)
plt.show()

# %%
#DO NOT TOUCH ME

# %% [markdown]
# **Create an area plot of all the columns for just the rows up to 30. (hint: use .ix).**

# %%
df4 = df3.loc[:30,:] #didnt work with .ix

df4.plot.area(alpha=0.5)
plt.tick_params(axis='both',direction='out',top=True,right=True)
          
plt.legend(loc=1)
plt.show()

# %%
#DO NOT TOUCH ME

# %% [markdown]
# ## Bonus Challenge!
# Note, you may find this really hard, reference the solutions if you can't figure it out!
# ** Notice how the legend in our previous figure overlapped some of actual diagram. Can you figure out how to display the legend outside of the plot as shown below?**
#
# **Try searching Google for a good stackoverflow link on this topic. If you can't find it on your own - [use this one for a hint.](http://stackoverflow.com/questions/23556153/how-to-put-legend-outside-the-plot-with-pandas)**

# %%
df4 = df3.loc[:30,:] #didnt work with .ix

df4.plot.area(alpha=0.5, linewidth= .1)

          
leg = plt.legend(bbox_to_anchor=(1.15, 0.7),
           loc=1,
          markerscale=1)
    
plt.tick_params(axis='both',direction='out',top=True,right=True)
plt.show()

# %%
#DO NOT TOUCH ME

# %% [markdown]
# # Great Job!
