# %%
import pandas as pd

# %%
df = pd.read_csv('Datasets/dataset_5secondWindow.csv')

# %%
user = ['U1']
df_user_1 = df[df.user.isin(user)]
df_user_2 = df[df.user.isin(['U2'])]
df_user_3 = df[df.user.isin(['U3'])]
df_user_4 = df[df.user.isin(['U4'])]
df_user_5 = df[df.user.isin(['U5'])]
df_user_6 = df[df.user.isin(['U6'])]
df_user_7 = df[df.user.isin(['U7'])]
df_user_8 = df[df.user.isin(['U8'])]
df_user_9 = df[df.user.isin(['U9'])]
df_user_10 = df[df.user.isin(['U10'])]
df_user_11 = df[df.user.isin(['U11'])]
df_user_12 = df[df.user.isin(['U12'])]

# %%
df_user_1.sort_values(by=['target'])
# Out:
#       Unnamed: 0    id   time  activityrecognition#0  activityrecognition#1  \
# 4834        4834   146   53.0                    NaN                    8.0
# 5213        5213   538   70.0                    NaN                  100.0
# 2667        2667   454   63.0                    NaN                  100.0
# 4455        4455   345   37.0                    NaN                  100.0
# 5211        5211   308  124.0                    NaN                   54.0
# ...          ...   ...    ...                    ...                    ...
# 2105        2105  7865  163.0                    NaN                  100.0
# 2099        2099  8656   46.0                    NaN                  100.0
# 2058        2058  6936   34.0                    NaN                  100.0
# 4643        4643  7296   95.0                    NaN                  100.0
# 5892        5892  8278   55.0                    NaN                  100.0
#
# ...

# %%
display(df_user_1.target.unique().tolist())
display(df_user_2.target.unique().tolist())
display(df_user_3.target.unique().tolist())
display(df_user_4.target.unique().tolist())
display(df_user_5.target.unique().tolist())
display(df_user_6.target.unique().tolist())
display(df_user_7.target.unique().tolist())
display(df_user_8.target.unique().tolist())
display(df_user_9.target.unique().tolist())
display(df_user_10.target.unique().tolist())
# Out:
# ['Car', 'Bus', 'Train', 'Still', 'Walking']
# ['Walking', 'Still', 'Car']
# ['Walking', 'Bus', 'Train']
# ['Walking', 'Car', 'Still']
# ['Walking', 'Still']
# ['Walking', 'Car', 'Still', 'Bus', 'Train']
# ['Train', 'Bus']
# ['Car', 'Still']
# ['Train', 'Walking']
# ['Still', 'Car', 'Walking']

# %%
test_car  = df_user_5[(df_user_5['target'] == 'Car')]
test_bus  = df_user_5[(df_user_5['target'] == 'Bus')]
test_train  = df_user_5[(df_user_5['target'] == 'Train')]
test_still  = df_user_5[(df_user_5['target'] == 'Still')]
test_walking  = df_user_5[(df_user_5['target'] == 'Walking')]

# %%
print(len(df_user_5))
print(len(test_walking))
print(len(test_still))
# Out:
# 17
# 11
# 6

# %%
# create timeframe sort_list
import random
len_of_col = len(test_walking)
min_time_slot = 2
random_gen = random.randint(1,len_of_col)
print('random_gen:',random_gen)
count_col_rest = len(df_user_5)
count_col_have = 0
print('count_have:',count_col_have)
print('count_rest:',count_col_rest)
df_sort = test_walking[count_col_have:n]
count_col_have += random_gen
count_col_rest -= random_gen
print('count_have:',count_col_have)
print('count_rest:',count_col_rest)
# Out:
# random_gen: 2
# count_have: 0
# count_rest: 17
# count_have: 2
# count_rest: 15

# %%
df_sort
# Out:
#       Unnamed: 0     id  time  activityrecognition#0  activityrecognition#1  \
# 640          640  20308  23.0                    NaN                  100.0
# 1296        1296  20330  45.0                    NaN                  100.0
# 1619        1619  20292   7.0                    NaN                  100.0
# 2111        2111  20314  29.0                    NaN                  100.0
# 2213        2213  20332  47.0                    NaN                  100.0
# 2314        2314  20299  14.0                    NaN                  100.0
# 2352        2352  20319  34.0                    NaN                  100.0
# 3650        3650  20338  53.0                    NaN                  100.0
#
#       android.sensor.accelerometer#mean  android.sensor.accelerometer#min  \
# 640                            9.746732                          3.348920
# 1296                          11.333011                          3.124888
# ...

# %%
display(test_car.head())
display(test_bus.head())
display(test_train.head())
display(test_still.head())
display(test_walking.head())
# Out:
#     Unnamed: 0    id   time  activityrecognition#0  activityrecognition#1  \
# 4            4   876   77.0                    NaN                  100.0
# 13          13  1937  563.0                    NaN                  100.0
# 17          17  2324   37.0                    NaN                  100.0
# 21          21  1204  238.0                    NaN                  100.0
# 30          30  1869  495.0                    NaN                  100.0
#
#     android.sensor.accelerometer#mean  android.sensor.accelerometer#min  \
# 4                            9.993466                          8.965621
# 13                           9.932078                          9.608102
# 17                           9.528492                          9.051952
# 21                           9.764914                          8.099912
# 30                           9.935582                          9.247339
#
#     android.sensor.accelerometer#max  android.sensor.accelerometer#std  \
# ...
