# %%
for epoch in range(epochs):
    for x_batch, y_batch in data:
        train()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7877c7c9008a> in <module>
# ----> 1 for epoch in range(epochs):
#       2     for x_batch, y_batch in data:
#       3         train()
#
# NameError: name 'epochs' is not defined

# %%
features = [1,2,3,4]
labels = [0,0,1,1]

data = features, labels

# %%
for x,y in data:
    print(x)
    print(y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-4be9a342963d> in <module>
# ----> 1 for x,y in data:
#       2     print(x)
#       3     print(y)
#
# ValueError: too many values to unpack (expected 2)

# %%
for x, y in zip(features,labels):
    print(x,y)
# Out:
# 1 0
# 2 0
# 3 1
# 4 1

# %%
import torch 
import torchvision
from torch.utils.data import Dataset, DataLoader
import numpy as np
import pandas as pd

# %%
class CustomDataset(Dataset): 
    def __init__(self):#constructer : __something__ is called automatically from python
        pass
    def __getitem__(self, index): #function ex. to index the list(iterator) //getitem standard in python
        pass
    def __len__(self): # len(dataset)
        pass

# %%
dataset_path = "https://people.sc.fsu.edu/~jburkardt/data/csv/homes.csv"

# %%
houses = pd.read_csv(dataset_path)

# %%
columns = [X.replace('"',"").replace(" ","") for x in houses.columns]
columns = ['Living','Rooms','Beds','Baths','Age','Acres','Taxes']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-229889c26c64> in <module>
# ----> 1 columns = [X.replace('"',"").replace(" ","") for x in houses.columns]
#       2 columns = ['Living','Rooms','Beds','Baths','Age','Acres','Taxes']
#
# <ipython-input-32-229889c26c64> in <listcomp>(.0)
# ----> 1 columns = [X.replace('"',"").replace(" ","") for x in houses.columns]
#       2 columns = ['Living','Rooms','Beds','Baths','Age','Acres','Taxes']
#
# AttributeError: 'list' object has no attribute 'replace'

# %%
print('Above 152',(houses.Sell.values > 152).sum())  #to get the array form from list // above 152 
print('Below 152',(houses.Sell.values <= 152).sum())

# %% [markdown]
# overwrite python class

# %%
class HouseDataset(Dataset):
    def __init__(self, csv_path, budget = 152):
        df = pd.read_csv(csv_path)
        df.columns = [x.replace('"',"").replace(" ","") for x in df.columns]
        columns = ['Living','Rooms','Beds','Baths','Age','Acres','Taxes']
        self.features = df[columns].values
        self.labels = (df.Sell.values <= budget).astype("int") #make true and false in 1 or 0
        self.n_samples = len(self.features)
    def __getitem__(self, index):
        pass
    def __len__(self):
        pass

# %%
trial = HouseDataset(dataset_path,budget =152)

# %%
dir(trial) # all function we can call with this particalar name // we can overide them
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__orig_bases__',
#  '__parameters__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_is_protocol']
